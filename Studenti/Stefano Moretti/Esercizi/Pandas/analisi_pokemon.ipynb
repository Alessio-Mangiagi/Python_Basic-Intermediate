# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

df = pd.read_csv('pokemon1_5gen.csv')

# %%
df.head(10)
# Out:
#    Pokemon Id  Pokedex Number Pokemon Name Legendary Type Primary Type  \
# 0           1               1    Bulbasaur            NaN        Grass
# 1           2               2      Ivysaur            NaN        Grass
# 2           3               3     Venusaur            NaN        Grass
# 3           5               4   Charmander            NaN         Fire
# 4           6               5   Charmeleon            NaN         Fire
# 5           7               6    Charizard            NaN         Fire
# 6          10               7     Squirtle            NaN        Water
# 7          11               8    Wartortle            NaN        Water
# 8          12               9    Blastoise            NaN        Water
# 9          32              10     Caterpie            NaN          Bug
#
#   Secondary Type Primary Ability Secondary Ability Hidden Ability  \
# 0         Poison        Overgrow               NaN    Chlorophyll
# ...

# %%
fig = plt.figure(figsize=(18, 12)) # Dimensione della figura
fig.patch.set_facecolor('lightblue')  # Colore di sfondo della figura

fig.suptitle('Frequenza delle Statistiche di tutti i Pokémon dalla 1ª alla 5ª Generazione', fontsize=20, fontweight='bold')

# Statistiche totali (sopra, tutta la riga)
ax1 = plt.subplot2grid((3, 3), (0, 1))
ax1.hist(df['Base Stat Total'], bins=20, color='paleturquoise', edgecolor='black')
ax1.set_title('Statistiche totali') 
ax1.set_xlabel('Totale')
ax1.set_ylabel('Frequenza')
ax1.grid(axis='y', alpha=0.75)

# PS
ax2 = plt.subplot2grid((3, 3), (1, 0))
ax2.hist(df['Health Stat'], bins=20, color='lightpink', edgecolor='black')
ax2.set_title('Punti Salute (PS)')
ax2.set_xlabel('PS')
ax2.set_ylabel('Frequenza')
ax2.grid(axis='y', alpha=0.75)

# Attacco
ax3 = plt.subplot2grid((3, 3), (1, 1))
ax3.hist(df['Attack Stat'], bins=20, color='saddlebrown', edgecolor='black')
ax3.set_title('Attacco')
ax3.set_xlabel('Attacco')
ax3.set_ylabel('Frequenza')
ax3.grid(axis='y', alpha=0.75)
ax3.set_xlim(right=250)  
ax3.set_ylim(top=160)  # Imposta il limite superiore dell'asse y

# Difesa
ax4 = plt.subplot2grid((3, 3), (1, 2))
ax4.hist(df['Defense Stat'], bins=20, color='slategrey', edgecolor='black')
ax4.set_title('Difesa')
ax4.set_xlabel('Difesa')
ax4.set_ylabel('Frequenza')
ax4.grid(axis='y', alpha=0.75)
ax4.set_xlim(right=250)  
ax4.set_ylim(top=160)

# Attacco Speciale
ax5 = plt.subplot2grid((3, 3), (2, 0))
ax5.hist(df['Special Attack Stat'], bins=20, color='mediumorchid', edgecolor='black')
ax5.set_title("Attacco Speciale")
ax5.set_xlabel('Attacco Speciale')
ax5.set_ylabel('Frequenza')
ax5.grid(axis='y', alpha=0.75)
ax5.set_xlim(right=250)  
ax5.set_ylim(top=160)

# Difesa Speciale
ax6 = plt.subplot2grid((3, 3), (2, 1))
ax6.hist(df['Special Defense Stat'], bins=20, color='tan', edgecolor='black')
ax6.set_title("Difesa Speciale")
ax6.set_xlabel('Difesa Speciale')
ax6.set_ylabel('Frequenza')
ax6.grid(axis='y', alpha=0.75)
ax6.set_xlim(right=250)  
ax6.set_ylim(top=160)

# Velocità
ax7 = plt.subplot2grid((3, 3), (2, 2))
ax7.hist(df['Speed Stat'], bins=20, color='gold', edgecolor='black')
ax7.set_title("Velocità")
ax7.set_xlabel('Velocità')
ax7.set_ylabel('Frequenza')
ax7.grid(axis='y', alpha=0.75)
ax7.set_xlim(right=250)  
ax7.set_ylim(top=160)

plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(18, 10))


# Grafico in alto al centro (occupa le prime due colonne)
ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
sns.barplot(data=media_per_tipo_totale, x='Tipo', y='Media Statistiche Totali', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax1)
ax1.set_title('Media delle Statistiche Totali per Tipo (Primario + Secondario)')
ax1.set_xlabel('Tipo')
ax1.set_ylabel('Media Statistiche Totali')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
ax1.grid(axis='y', alpha=0.5)
ax1.set_ylim(0, 600)

# Grafico in basso a sinistra
ax2 = plt.subplot2grid((2, 2), (1, 0))
sns.barplot(data=media_per_tipo1_df, x='Tipo', y='Media Statistiche Totali', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax2)
ax2.set_title('Media Statistiche Totali per Primo Tipo')
ax2.set_xlabel('Tipo 1')
ax2.set_ylabel('Media Statistiche Totali')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
ax2.grid(axis='y', alpha=0.5)
ax2.set_ylim(0, 600)

# Grafico in basso a destra
ax3 = plt.subplot2grid((2, 2), (1, 1))
sns.barplot(data=media_per_tipo2_df, x='Tipo', y='Media Statistiche Totali', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax3)
ax3.set_title('Media Statistiche Totali per Secondo Tipo')
ax3.set_xlabel('Tipo 2')
ax3.set_ylabel('Media Statistiche Totali')
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45)
ax3.grid(axis='y', alpha=0.5)
ax3.set_ylim(0, 600)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 5
#       3 # Grafico in alto al centro (occupa le prime due colonne)
#       4 ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
# ----> 5 sns.barplot(data=media_per_tipo_totale, x='Tipo', y='Media Statistiche Totali', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax1)
#       6 ax1.set_title('Media delle Statistiche Totali per Tipo (Primario + Secondario)')
#       7 ax1.set_xlabel('Tipo')
#
# NameError: name 'media_per_tipo_totale' is not defined

# %%
fig = plt.figure(figsize=(18, 10))

# Grafico in alto centrato (colonna centrale)
ax1 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
sns.barplot(data=type_counts_df, x='Tipo', y='Numero', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax1)
ax1.set_title('Distribuzione totale dei Pokémon per Tipo')
ax1.set_xlabel('Tipo')
ax1.set_ylabel('Numero di Pokémon')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
ax1.grid(axis='y', alpha=0.5)

# Grafico in basso a sinistra
ax2 = plt.subplot2grid((2, 2), (1, 0))
sns.barplot(data=primary_counts, x='Tipo', y='Numero', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax2)
ax2.set_title('Distribuzione dei Pokémon per Tipo Primario')
ax2.set_xlabel('Tipo Primario')
ax2.set_ylabel('Numero di Pokémon')
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
ax2.grid(axis='y', alpha=0.5)
ax2.set_ylim(0, 110)  # Imposta il limite superiore dell'asse y

# Grafico in basso a destra
ax3 = plt.subplot2grid((2, 2), (1, 1))
sns.barplot(data=secondary_counts, x='Tipo', y='Numero', hue='Tipo', palette='viridis', dodge=False, legend=False, edgecolor='black', ax=ax3)
ax3.set_title('Distribuzione dei Pokémon per Tipo Secondario')
ax3.set_xlabel('Tipo Secondario')
ax3.set_ylabel('Numero di Pokémon')
ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45)
ax3.grid(axis='y', alpha=0.5)
ax3.set_ylim(0, 110)  # Imposta il limite superiore dell'asse y

plt.tight_layout()
plt.show()
# Out:
# C:\Users\stefy\AppData\Local\Temp\ipykernel_28912\4244423455.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(ax1.get_xticklabels(), rotation=45)
# C:\Users\stefy\AppData\Local\Temp\ipykernel_28912\4244423455.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
# C:\Users\stefy\AppData\Local\Temp\ipykernel_28912\4244423455.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax3.set_xticklabels(ax3.get_xticklabels(), rotation=45)
